# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
dir='D:/Python/seg-data/data_MB/test/src'

# %%
data=np.load(dir+'/0.npy')

# %%
(255*data[0]/(data[0].max()))
# Out:
# array([[ 12.47137298,  10.91217343,  10.34519177, ...,  18.14118955,
#          17.14897165, -14.8860478 ],
#        [ 16.86548082,  10.34519177,  10.91217343, ...,  17.00722624,
#          17.85769872,  16.29849917],
#        [ 12.47137298,   9.77821012,  13.46359088, ...,  17.29071707,
#          17.29071707, -17.57921067],
#        ...,
#        [ -8.22401334, -12.19288494,  16.29849917, ...,   1.55586437,
#          -0.99555309,   1.13062813],
#        [-11.05892162,  15.16453585,  11.47915509, ...,   3.25680934,
#          -1.1372985 ,   2.68982768],
#        [-10.91717621,  14.03057254,  10.6286826 , ...,   3.39855475,
#           1.55586437,  -0.99555309]])

# %%
cv.imshow(' ',255*data[0]/data[0].max())

# %%
plt.imshow(data[2])
